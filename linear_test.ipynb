# %% [markdown]
# <a href="https://colab.research.google.com/github/ktgokr/machineLearning/blob/main/linear_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
import csv
from google.colab import files
uploaded = files.upload()

f = open('tfile.csv', encoding ='utf8')
data = pd.read_csv(f)
# Out:
#      <input type="file" id="files-113f49e4-bab4-461e-a330-42155eb49933" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-113f49e4-bab4-461e-a330-42155eb49933">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tfile.csv to tfile.csv

# %%
data.head

# %%
data.info()

# %%
data.columns=['mpg','cylinder','displacement','horsepower','weight', 'acceleration','model_year', 'origin','name']

# %%
data.head

# %%
data.describe()

# %%
data.plot(kind='scatter', x ='weight', y='mpg', c='coral',s =10, figsize=(10,5))
plt.show()
data.plot(kind='scatter', x ='weight', y='acceleration', c='coral',s =10, figsize=(10,5))
plt.show()

# %%
X = data['weight'] #입력데이터
Y = data['mpg'] #출력데이터
sns.scatterplot(x = X, y=Y)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#train and test split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2)

# %%
#선형회귀모델선언
lr = LinearRegression()

# %%
#선형회귀 모델 학습
#reshape 부분 유의
lr.fit(X_train.values.reshape(-1,1), Y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
#테스트 데이터에 대한 예측을 수행
Y_pred = lr.predict(X_test.values.reshape(-1,1))

# %%
Y_test
# Out:
# 52     31.0
# 164    20.0
# 305    28.8
# 350    34.4
# 48     23.0
#        ...
# 37     14.0
# 171    25.0
# 282    20.2
# 174    29.0
# 198    20.0
# Name: mpg, Length: 80, dtype: float64

# %%
X_test.shape
# Out:
# (80,)

# %%
#MSE(Mean Squared Error)를 측정합니다.
MSE = mean_squared_error(Y_test, Y_pred)

#RMSE(Root Mean Squared Error)를 측정합니다.
RMSE = np.sqrt(MSE)

print("MSE: ", MSE)
print("RMSE: ", RMSE)
# Out:
# MSE:  22.956659547408552
# RMSE:  4.791310838111899

# %%
plt.plot(X_test, Y_test, 'o')
plt.plot(X_test, Y_pred)
plt.title("weight&mpg")
plt.show()
